# %%
import pandas as pd
import numpy as np
import sqlite3
with sqlite3.connect('data/chinook.db') as connection:
    df_employee = pd.read_sql(
        "SELECT * FROM customers",
        con=connection
    )
    print(df_employee.head(10))
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %%
df_iris = pd.read_json("data/iris.json")
print(df_iris.shape)
df_iris.columns
# Out:
# (150, 5)
# Index(['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species'], dtype='object')

# %%
df_titanic = pd.read_excel("data/titanic.xlsx")
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
flights = pd.read_parquet('data/flights')
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6729125 entries, 0 to 6729124
# Columns: 109 entries, Year to Div5TailNum
# dtypes: object(109)
# memory usage: 5.5+ GB

# %%
df_movie = pd.read_csv("data/movie.csv")
df_movie.sample(10)
# Out:
#                 color         director_name  num_critic_for_reviews  duration  \
# 3119  Black and White             Tony Kaye                   162.0     101.0
# 4052            Color          Paolo Monico                     2.0     100.0
# 3508            Color         James Cameron                   204.0     107.0
# 1206            Color        Bobby Farrelly                   109.0     114.0
# 3608            Color  Christophe Barratier                   112.0      97.0
# 3184            Color        Scott Marshall                    20.0      93.0
# 1799            Color           Alex Proyas                   222.0     111.0
# 1088            Color            Luis Llosa                    38.0     110.0
# 1207  Black and White          Oliver Stone                   125.0     206.0
# 1431            Color                   NaN                     3.0      60.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# ...

# %% [markdown]
# Part 2

# %%
new_columns = [column.lower() for column in df_iris.columns]
df_iris.columns = new_columns
df_iris[['sepallength',	'sepalwidth']]
# Out:
#      sepallength  sepalwidth
# 0            5.1         3.5
# 1            4.9         3.0
# 2            4.7         3.2
# 3            4.6         3.1
# 4            5.0         3.6
# ..           ...         ...
# 145          6.7         3.0
# 146          6.3         2.5
# 147          6.5         3.0
# 148          6.2         3.4
# 149          5.9         3.0
#
# [150 rows x 2 columns]

# %%
df_titanic[df_titanic["Age"] > 30]
df_titanic.value_counts("Sex")
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
new_columns1 = [column.lower() for column in flights.columns]
flights.columns = new_columns1
extract = flights[["origin", "dest"]]
unique = extract["dest"].nunique()
unique
# Out:
# 373

# %%
filtered_data = df_movie[df_movie["duration"]> 120]
filtered_data = filtered_data.sort_values(by=["director_facebook_likes"], ascending=False)

# %% [markdown]
# Part 3

# %%
numerical_columns = df_iris.select_dtypes("number")
numerical_columns.mean()
numerical_columns.median()
numerical_columns.std()
# Out:
# sepallength    0.828066
# sepalwidth     0.435866
# petallength    1.765298
# petalwidth     0.762238
# dtype: float64

# %%
df_titanic[["Age"]].min()
df_titanic[["Age"]].max()
df_titanic[["Age"]].sum()
# Out:
# Age    21205.17
# dtype: float64

# %%
filtered_data.head(1)[["director_name"]]
# Out:
#         director_name
# 66  Christopher Nolan

# %%
with_duration = df_movie.sort_values(by=["duration"], ascending=False)
with_duration.head()[["director_name", "movie_title"]]
# Out:
#             director_name               movie_title
# 1694                  NaN                   Trapped
# 2436                  NaN                    Carlos
# 1487      Taylor Hackford       Blood In, Blood Out
# 1134       Michael Cimino             Heaven's Gate
# 3254  Chatrichalerm Yukol  The Legend of Suriyothai

# %%
missing_values = flights.isnull().sum()
missing_values
for column in flights.select_dtypes("number").columns:
    flights[flights[column].isna()] = flights[column].mean()
